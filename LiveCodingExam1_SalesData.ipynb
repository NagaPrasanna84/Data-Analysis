# %% [markdown]
# # Live Coding Exam - To cleanse the data in the data set and create different ML models from the Github dataset

# %%
import numpy as np
import pandas as pd
Sales_Data = pd.read_csv("https://raw.githubusercontent.com/jhhalls/Online-Exam-Ds0124/main/Sales_LinReg.csv")
Sales_Data
# Out:
#      Republic  NDTV   TV5   TV9  AajTak  sales
# 0         8.7  48.9   4.0  75.0    49.0    7.2
# 1        57.5  32.8  65.9  23.5    57.5   11.8
# 2       120.2  19.6   7.2  11.6    18.5   13.2
# 3         8.6   2.1  46.0   1.0     2.6    4.8
# 4       199.8   2.6  52.9  21.2     2.9   10.6
# ..        ...   ...   ...   ...     ...    ...
# 300     286.0  13.9  35.2   3.7    13.9   15.9
# 301      18.7  12.1  23.7  23.4    18.7    6.7
# 302      39.5  41.1  17.6   5.8    39.5   10.8
# 303      75.5  10.8   8.3   6.0    75.5    9.9
# 304      17.2   4.1  30.0  31.6    17.2    5.9
#
# [305 rows x 6 columns]

# %%
#Export file to different folder by giving the path as below
Sales_Data.to_csv(r'C:\Users\Prasanna\Documents\Prasanna\AI_DS & ML Coaching\Sales_DataLinReg.csv', 
           index=False, header=True )

# %%
#Let's start with importing necessary libraries
import numpy as np
import pandas as pd

from sklearn.preprocessing import StandardScalar
from sklearn.linear_model import LinearRegression
from sklear.model_selection import train_test_split
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import pickle
import warnings 
warnings.filterwarnings('ignore')

# %%
Sales_Data.head()
# Out:
#    Republic  NDTV   TV5   TV9  AajTak  sales
# 0       8.7  48.9   4.0  75.0    49.0    7.2
# 1      57.5  32.8  65.9  23.5    57.5   11.8
# 2     120.2  19.6   7.2  11.6    18.5   13.2
# 3       8.6   2.1  46.0   1.0     2.6    4.8
# 4     199.8   2.6  52.9  21.2     2.9   10.6

# %%
#Data Preprocessing
#1. EDA Analysis(Exploratory Data Anlysis)
# 2. Data Cleansing
# 3. Finding and treating Outliers(if any)
# 4. Feature selection for model building(Dropping unwanted columns)

Sales_Data.describe()
# Out:
#          Republic        NDTV         TV5         TV9      AajTak       sales
# count  295.000000  300.000000  305.000000  297.000000  300.000000  305.000000
# mean   148.136610   22.341333   29.459344   28.862626   23.517967   13.811475
# std     87.330161   14.781927   20.290023   21.411180   15.853789    5.192185
# min      0.700000    0.300000    0.300000    0.300000    0.300000    1.600000
# 25%     74.050000    9.125000   15.900000   10.900000   10.000000   10.300000
# 50%    149.800000   21.050000   26.200000   23.500000   21.300000   12.800000
# 75%    221.450000   35.650000   39.600000   43.000000   36.900000   17.200000
# max    296.400000   49.400000  114.000000  114.000000   75.500000   27.000000

# %%
Sales_Data.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 Sales_Data.info()
#
# NameError: name 'Sales_Data' is not defined

# %%
#finding the count of missing values from different columns
Sales_Data.isna().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 #finding the count of missing values from different columns
# ----> 2 Sales_Data.isna().sum()
#
# NameError: name 'Sales_Data' is not defined

# %%
Sales_Data.describe()
# Out:
#          Republic        NDTV         TV5         TV9      AajTak       sales
# count  295.000000  300.000000  305.000000  297.000000  300.000000  305.000000
# mean   148.136610   22.341333   29.459344   28.862626   23.517967   13.811475
# std     87.330161   14.781927   20.290023   21.411180   15.853789    5.192185
# min      0.700000    0.300000    0.300000    0.300000    0.300000    1.600000
# 25%     74.050000    9.125000   15.900000   10.900000   10.000000   10.300000
# 50%    149.800000   21.050000   26.200000   23.500000   21.300000   12.800000
# 75%    221.450000   35.650000   39.600000   43.000000   36.900000   17.200000
# max    296.400000   49.400000  114.000000  114.000000   75.500000   27.000000

# %%
#Filling null values if any
Sales_Data['Republic'] =Sales_Data['Republic'] .fillna(Sales_Data['Republic'].mean())
Sales_Data['NDTV'] =Sales_Data['NDTV'] .fillna(Sales_Data['NDTV'].mean())
Sales_Data['TV5'] =Sales_Data['TV5'] .fillna(Sales_Data['TV5'].mean())
Sales_Data['TV9'] =Sales_Data['TV9'] .fillna(Sales_Data['TV9'].mean())
Sales_Data['AajTak'] =Sales_Data['AajTak'] .fillna(Sales_Data['AajTak'].mean())
Sales_Data.describe()
# Out:
#          Republic        NDTV         TV5         TV9      AajTak       sales
# count  305.000000  305.000000  305.000000  305.000000  305.000000  305.000000
# mean   148.136610   22.341333   29.459344   28.862626   23.517967   13.811475
# std     85.881799   14.659861   20.290023   21.127576   15.722872    5.192185
# min      0.700000    0.300000    0.300000    0.300000    0.300000    1.600000
# 25%     75.100000    9.300000   15.900000   11.000000   10.100000   10.300000
# 50%    148.136610   21.300000   26.200000   24.200000   21.700000   12.800000
# 75%    220.300000   35.600000   39.600000   41.800000   36.800000   17.200000
# max    296.400000   49.400000  114.000000  114.000000   75.500000   27.000000

# %%
plt.figure(figsize=(50,15), facecolor='blue')
plotnumber = 1

for column in Sales_Data:
    if plotnumber<=8:
        ax= plt.subplot(2,3,plotnumber)
        sns.histplot(Sales_Data[column])
        plt.xlabel(column,fontsize = 30)
        
    plotnumber+=1
plt.tight_layout()

# %%
y= Sales_Data['sales']
X= Sales_Data.drop(columns=['sales'])
y
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 y= Sales_Data['sales']
#       2 X= Sales_Data.drop(columns=['sales'])
#       3 y
#
# NameError: name 'Sales_Data' is not defined

# %%
plt.figure(figsize=(20,15), facecolor='blue')
plotnumber = 1

for column in Sales_Data:
    if plotnumber<=8:
        ax= plt.subplot(2,3,plotnumber)
        plt.scatter(Sales_Data[column],y)
        plt.xlabel(column,fontsize=20)
        plt.ylabel('Sales',fontsize =10)             
             
    plotnumber+=1
plt.tight_layout()

# %%
#Still so much to do derive the model
#We have to seperate the features and labels which is like test data and train data
# From them we can again derive some more points to create the model
# But here I am not understanding this error why the table name ('Sales_Data') is displaying as not defined which has been executed previously.
# So uploading this code till here in Github and providing the link in LMS. Kindly check
